# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset('tips')
ax=plt.subplots()
ax=sns.distplot(tips['total_bill'],kde=True) #확률밀도함수, 면적의합이 1
ax.set_title("total bill histogram")
# Out:
# Text(0.5, 1.0, 'total bill histogram')

# %%
tips=sns.load_dataset('tips')
ax=plt.subplots()
ax=sns.countplot(tips['day'])
#ax=sns.countplot('day','tips')
ax.set_title("visitors per day")
# Out:
# Text(0.5, 1.0, 'visitors per day')

# %%
ax=plt.subplots()
ax=sns.regplot(x='total_bill',y='tip',data=tips, fit_reg=True)

# %%
ax=sns.jointplot(x='total_bill',y='tip',data=tips, kind='hex') #???

# %%
#밀집도 그래프 토탈빌 대비 팁스의 분포 경향
ax=plt.subplots()
sns.kdeplot(data=tips['total_bill'], data2=tips['tip'])

# %%
ax=plt.subplots()
ax=sns.barplot(x='time', y='total_bill', data=tips)

ax.set_title("lunch vs dinner sales")
# Out:
# Text(0.5, 1.0, 'lunch vs dinner sales')

# %%
ax=plt.subplots()
ax=sns.boxplot(x='time', y='total_bill', data=tips)

ax.set_title("lunch vs dinner sales")
# Out:
# Text(0.5, 1.0, 'lunch vs dinner sales')

# %%
ax=plt.subplots()
ax=sns.violinplot(x='time', y='total_bill', data=tips)

ax.set_title("lunch vs dinner sales")
# Out:
# Text(0.5, 1.0, 'lunch vs dinner sales')

# %%
sns.pairplot(tips)

# %%
pairGrid=sns.PairGrid(tips)
pairGrid=pairGrid.map_upper(sns.regplot)
pairGrid=pairGrid.map_lower(sns.kdeplot)
pairGrid=pairGrid.map_diag(sns.distplot, rug=True)

# %% [markdown]
# lmplot? hue 옵션으로 데이터에따라서 색깔 다르게

# %%
sns.regplot(x='total_bill',y='tip', data=tips, fit_reg=False, 
          scatter_kws={'s':tips['size']*20})

# %%
sns.lmplot(x='total_bill',y='tip', data=tips, fit_reg=False, hue='time',
          scatter_kws={'s':50})

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
sns.pairplot(tips, hue='sex') #성별에 대한 산점도, 밀도 그래프

# %%
#한글 깨지는 경우
import matplotlib
from matplotlib import font_manager, rc
import platform
if platform.system()=="Windows":
    font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus']=False

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# https://matplotlib.org/2.0.2/examples/color/named_colors.html 에서 색상표 확인

# %%
plt.title('한글 되나')
plt.plot([10,20,30,40],[1,4,9,16], 'rs--') #red square 선종류

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b",
         lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.title("스타일 적용 예")
plt.xlim(0, 50) #x범위
plt.ylim(-10, 30) #y 범위

plt.show()

# %%
import numpy as np
X=np.linspace(-np.pi, np.pi, 256)
C,S= np.cos(X), np.sin(X)
plt.title('legend를 표시한 플롯')
plt.plot(X, C, ls='--', label='cosine')
plt.plot(X, S, ls=':', label='sine')
plt.legend(loc=10)
plt.xlabel('time')
plt.ylabel('amp')
plt.show()

# %%
plt.plot(x,y)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
# Out:
# ([<matplotlib.axis.YTick at 0x193d0632cd0>,
#   <matplotlib.axis.YTick at 0x193d05fa430>,
#   <matplotlib.axis.YTick at 0x193d05fac70>],
#  [Text(0, 0, 'Low'), Text(0, 0, 'Zero'), Text(0, 0, 'High')])

# %%
plt.plot(t,t,'r--',t,0.5*t**2, 'bs:',t,0.2*t**3, 'g^-')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-8051cd4dd5bc> in <module>
# ----> 1 plt.plot(t,t,'r--',t,0.5*t**2, 'bs:',t,0.2*t**3, 'g^-')
#
# NameError: name 't' is not defined

# %%
plt.plot([1, 4, 9, 16],label='blue',
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.plot([9, 16, 4, 1],label='black',
         c="k", lw=3, ls=":", marker="s", ms=10, mec="m", mew=5, mfc="c")
plt.legend(loc=2)

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10, 3)) #size 1: 72px
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(figsize=(5,4))
plt.title("현재의 Figure 객체")
plt.plot([1, 2, 3, 4,5,6,7,6,3,4,3,2,4,5,6,6,7,7,5,4,4,3,2,4,6,3,3,3], 'ro:')
plt.figure(1)
f2=plt.gcf()
print(f2, id(f2))
# Out:
# Figure(360x288) 2616695586480

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
# Out:
# Text(0, 0.5, 'Undamped')

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")
# Out:
# Text(0.5, 1.0, 'axes 4')

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("2개의 y축 한 figure에서 사용하기")
ax0.plot([10, 5, 2, 9, 7], 'r-', label="y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label="y1")
ax1.set_ylabel("y1")
ax1.grid(False)
ax0.set_xlabel("공유되는 x축")
fig.legend(loc=10)
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pylab as plt

y = [2, 3, 1]
x = np.arange(len(y))
xlabel = ['가', '나', '다']
plt.title("Bar Chart")
plt.bar(x, y)
plt.xticks(x, xlabel)
plt.yticks(sorted(y))
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
x = np.linspace(0.1, 2 * np.pi, 10)
plt.title("Stem Plot")
plt.stem(x, np.cos(x), '-.')
plt.show()

# %%
labels = ['개구리', '돼지', '개', '통나무']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0)
plt.title("Pie Chart")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %%
x=np.linspace(-np.pi,np.pi,256)
c=np.cos(x)
with plt.xkcd():
    plt.title('XKCD style plot')
    plt.plot(x,c,label='cosine')
    t=2*np.pi/3
    plt.scatter(t,np.cos(t),50,color='red')
    plt.annotate(r'0.5 Here!', xy=(t,np.cos(t)), xycoords='data', xytext=(-90,-50),
                textcoords='offset points', fontsize=16, arrowprops=dict(arrowstyle="->"))

# %% [markdown]
# 영상 가져오기

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('ncfgAQ1542k')

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2
plt.title("Bubble Chart")
plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title("mnist digits; 0")
plt.imshow(X, interpolation='nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %%
methods = [
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
    'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
    'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos'
]
fig, axes = plt.subplots(3, 6, figsize=(12, 6),
                         subplot_kw={'xticks': [], 'yticks': []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap=plt.cm.bone_r, interpolation=interp_method)
    ax.set_title(interp_method)
plt.show()

# %%
iris = sns.load_dataset("iris")    # 붓꽃 데이터
titanic = sns.load_dataset("titanic")    # 타이타닉호 데이터
tips = sns.load_dataset("tips")    # 팁 데이터
flights = sns.load_dataset("flights")    # 여객운송 데이터

# %%
sns.kdeplot(iris.petal_length)
plt.title("Iris 데이터 중, 꽃잎의 길이에 대한 Kernel Density Plot")
plt.show()

# %%
sns.distplot(iris.petal_length, kde=True, rug=True)
plt.title("Iris 데이터 중, 꽃잎의 길이에 대한 Dist Plot")
plt.show()

# %%
sns.countplot(tips.day, data=tips)
plt.title("요일별 팁을 준 횟수")
plt.show()

# %%
sns.pairplot(iris, hue='species', markers=['o','s','d'])
